# %%
import pandas as pd

# %%
df=pd.read_csv("data set.csv")

# %%
df.shape
# Out:
# (30, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.dropna()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(1)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %% [markdown]
# # Data cleaning

# %%
df.head(5)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail(5)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df['Salary'].mean()# Take out average
# Out:
# 76004.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.values
# Out:
# array([[0.00000e+00, 1.20000e+00, 3.93440e+04],
#        [1.00000e+00, 1.40000e+00, 4.62060e+04],
#        [2.00000e+00, 1.60000e+00, 3.77320e+04],
#        [3.00000e+00, 2.10000e+00, 4.35260e+04],
#        [4.00000e+00, 2.30000e+00, 3.98920e+04],
#        [5.00000e+00, 3.00000e+00, 5.66430e+04],
#        [6.00000e+00, 3.10000e+00, 6.01510e+04],
#        [7.00000e+00, 3.30000e+00, 5.44460e+04],
#        [8.00000e+00, 3.30000e+00, 6.44460e+04],
#        [9.00000e+00, 3.80000e+00, 5.71900e+04],
#        [1.00000e+01, 4.00000e+00, 6.32190e+04],
#        [1.10000e+01, 4.10000e+00, 5.57950e+04],
#        [1.20000e+01, 4.10000e+00, 5.69580e+04],
#        [1.30000e+01, 4.20000e+00, 5.70820e+04],
#        [1.40000e+01, 4.60000e+00, 6.11120e+04],
#        [1.50000e+01, 5.00000e+00, 6.79390e+04],
#        [1.60000e+01, 5.20000e+00, 6.60300e+04],
#        [1.70000e+01, 5.40000e+00, 8.30890e+04],
#        [1.80000e+01, 6.00000e+00, 8.13640e+04],
#        [1.90000e+01, 6.10000e+00, 9.39410e+04],
# ...

# %%
df['Salary'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Salary'>

# %%
df['Salary'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Salary'>

# %%
df['Salary'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Salary'>

# %%
df['Salary'].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Salary'>

# %%
df['Salary'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['Salary'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df.describe(include="all")
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
a=df['Salary']
print(a)
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Preprocessing

# %%
df.isnull()
# Out:
#     Unnamed: 0  YearsExperience  Salary
# 0        False            False   False
# 1        False            False   False
# 2        False            False   False
# 3        False            False   False
# 4        False            False   False
# 5        False            False   False
# 6        False            False   False
# 7        False            False   False
# 8        False            False   False
# 9        False            False   False
# 10       False            False   False
# 11       False            False   False
# 12       False            False   False
# 13       False            False   False
# 14       False            False   False
# 15       False            False   False
# 16       False            False   False
# 17       False            False   False
# 18       False            False   False
# 19       False            False   False
# 20       False            False   False
# 21       False            False   False
# ...

# %%
df.sample(5)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 8            8              3.3   64446.0
# 3            3              2.1   43526.0
# 18          18              6.0   81364.0
# 29          29             10.6  121873.0
# 7            7              3.3   54446.0

# %% [markdown]
# # slicing

# %%
df[3:5]
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df[3:4:6]
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 3           3              2.1  43526.0

# %%
df[['Salary']][1:5]
# Out:
#     Salary
# 1  46206.0
# 2  37732.0
# 3  43526.0
# 4  39892.0

# %% [markdown]
# # Adding

# %%
df['col']=5
df
# Out:
#     Unnamed: 0  YearsExperience    Salary  col
# 0            0              1.2   39344.0    5
# 1            1              1.4   46206.0    5
# 2            2              1.6   37732.0    5
# 3            3              2.1   43526.0    5
# 4            4              2.3   39892.0    5
# 5            5              3.0   56643.0    5
# 6            6              3.1   60151.0    5
# 7            7              3.3   54446.0    5
# 8            8              3.3   64446.0    5
# 9            9              3.8   57190.0    5
# 10          10              4.0   63219.0    5
# 11          11              4.1   55795.0    5
# 12          12              4.1   56958.0    5
# 13          13              4.2   57082.0    5
# 14          14              4.6   61112.0    5
# 15          15              5.0   67939.0    5
# 16          16              5.2   66030.0    5
# 17          17              5.4   83089.0    5
# 18          18              6.0   81364.0    5
# ...

# %% [markdown]
# # Remove column

# %%
df.drop(columns=['col'],inplace=True)
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %% [markdown]
# # Add a ROW

# %%
a=pd.DataFrame({'number_courses':50,
                'Mark':'19.202',
                'time_study':'0.096'},
               index=[0])
a
df=pd.concat([a,df])
df
# Out:
#     number_courses    Mark time_study  Unnamed: 0  YearsExperience    Salary
# 0             50.0  19.202      0.096         NaN              NaN       NaN
# 0              NaN     NaN        NaN         0.0              1.2   39344.0
# 1              NaN     NaN        NaN         1.0              1.4   46206.0
# 2              NaN     NaN        NaN         2.0              1.6   37732.0
# 3              NaN     NaN        NaN         3.0              2.1   43526.0
# 4              NaN     NaN        NaN         4.0              2.3   39892.0
# 5              NaN     NaN        NaN         5.0              3.0   56643.0
# 6              NaN     NaN        NaN         6.0              3.1   60151.0
# 7              NaN     NaN        NaN         7.0              3.3   54446.0
# 8              NaN     NaN        NaN         8.0              3.3   64446.0
# 9              NaN     NaN        NaN         9.0              3.8   57190.0
# ...

# %%
df['Salary'].median()#middle value
# Out:
# 65238.0

# %%
df.duplicated()
# Out:
# 0     False
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool
